# %% [markdown]
# # Question 1: Network Programming

# %%
import urllib.request, urllib.parse, urllib.error
import re
import ssl

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = input('Enter - ')
html = urllib.request.urlopen(url, context=ctx).read()
links = re.findall(b'href="(http[s]?://.*?)"', html)
for link in links:
    print(link.decode())
# Out:
# Enter - https://acharya.ac.in/
# https://fonts.googleapis.com/css?family=Open+Sans|Vast+Shadow&display=swap
# https://fonts.googleapis.com/icon?family=Material+Icons
# https://admissions.acharya.ac.in/
# https://wa.me/18147054141
# https://acharya.ac.in/faculty-ORIGINAL
# https://acharya.ac.in/international.html
# https://acharya.ac.in/admissions.html
# https://blog.acharya.ac.in/
# https://acharya.ac.in/Collaboration/index.php
# https://acharya.ac.in/transport#transport
# https://www.acharyainstitutes.in/index.php?r=student%2Flogin
# https://www.acharyainstitutes.in/
# https://www.acharyainstitutes.in/index.php?r=student%2Flogin
# https://www.acharyainstitutes.in/
# https://admissions.acharya.ac.in/
# https://acharya.ac.in/scholarship
# https://admissions.acharya.ac.in/
# https://admissions.acharya.ac.in/
# https://admissions.acharya.ac.in/
# https://admissions.acharya.ac.in/
# https://acharya.ac.in/Collaboration/index.php
# https://abmrcp.ac.in/pdf/Formularium%202021_%20Sept%20ABMRCP%207%2011%2021.pdf
# https://admissions.acharya.ac.in/
# https://api.whatsapp.com/send?phone=9731797677&text=I would like to visit acharya campus
# http://www.acharyahabba.in
# https://www.facebook.com/acharya.ac.in
# https://twitter.com/acharya_ac_in
# https://www.youtube.com/user/acharya7317
# https://www.instagram.com/acharyainstitutes/
# https://www.linkedin.com/school/acharya-institutes/
# https://wa.me/18147054141
# https://wa.me/919731766657
# https://goo.gl/maps/eLEf1aZGA6QpN6eH8
# https://www.acharyainstitutes.in/index.php?r=student%2Flogin
# https://www.acharyainstitutes.in/
# https://acharya.ac.in/extra/reports/PriPolicy.pdf
# https://www.acharya.ac.in/pdf/Mandatory_Disclosure_2017_18.pdf

# %% [markdown]
# # Question 2: Web Services

# %%
import requests

# %%
url_get='http://httpbin.org/get'
payload={"name":"Joseph","ID":"123"}
r=requests.get(url_get,params=payload)
r.url
print("request body:", r.request.body)
# Out:
# request body: None

# %%
print(r.status_code)
# Out:
# 200

# %%
print(r.text)
# Out:
# {
#   "args": {
#     "ID": "123",
#     "name": "Joseph"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.24.0",
#     "X-Amzn-Trace-Id": "Root=1-61e904ef-1665de972761b53054967106"
#   },
#   "origin": "223.231.159.242",
#   "url": "http://httpbin.org/get?name=Joseph&ID=123"
# }

# %%
r.headers['Content-Type']
# Out:
# 'application/json'

# %%
r.json()
# Out:
# {'args': {'ID': '123', 'name': 'Joseph'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.24.0',
#   'X-Amzn-Trace-Id': 'Root=1-61e904ef-1665de972761b53054967106'},
#  'origin': '223.231.159.242',
#  'url': 'http://httpbin.org/get?name=Joseph&ID=123'}

# %%
r.json()['args']
# Out:
# {'ID': '123', 'name': 'Joseph'}

# %% [markdown]
# # Post Requests

# %%
url_post='http://httpbin.org/post'
r_post=requests.post(url_post,data=payload)
print("POST request URL:",r_post.url )
print("GET request URL:",r.url)
# Out:
# POST request URL: http://httpbin.org/post
# GET request URL: http://httpbin.org/get?name=Joseph&ID=123

# %%
print("POST request body:",r_post.request.body)
print("GET request body:",r.request.body)
# Out:
# POST request body: name=Joseph&ID=123
# GET request body: None

# %%
r_post.json()['form']
# Out:
# {'ID': '123', 'name': 'Joseph'}

# %% [markdown]
# # Question 3 Database Concepts

# %%
import sqlite3

conn = sqlite3.connect('music.sqlite')
cur = conn.cursor()

cur.execute('DROP TABLE IF EXISTS Tracks')
cur.execute('CREATE TABLE Tracks (title TEXT, plays INTEGER)')
cur.execute('INSERT INTO Tracks (title, plays) VALUES (?, ?)', 
    ('Thunderstruck', 20))
cur.execute('INSERT INTO Tracks (title, plays) VALUES (?, ?)', 
    ('My Way', 15))
conn.commit()

print('Tracks:')
cur.execute('SELECT title, plays FROM Tracks')
for row in cur:
     print(row)

cur.execute('DELETE FROM Tracks WHERE plays < 100')
conn.commit()

conn.close()
# Out:
# Tracks:
# ('Thunderstruck', 20)
# ('My Way', 15)

# %% [markdown]
# ![image.png](attachment:image.png)
